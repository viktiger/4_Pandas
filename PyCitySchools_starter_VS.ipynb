# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="outer", on=["school_name", "school_name"])

school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculate the total number of schools
Total_schools_df = school_data_complete["school_name"].unique()
Total_schools_count_df = len(Total_schools_df)
Total_schools_count_df
# Out:
# 15

# %%
# Calculate the total number of students
Total_students_df = school_data_complete["student_name"].count()
Total_students_df = '{:,.0f}'.format(Total_students_df)
Total_students_df
# Out:
# '39,170'

# %%
# Calculate the total budget
Total_budget_df = school_data_complete["budget"].unique()
Total_budget_sum_df = Total_budget_df.sum()
Total_budget_sum_df = '${:,.0f}'.format(Total_budget_sum_df)
Total_budget_sum_df
# Out:
# '$24,649,428'

# %%
# Calculate the average math score
Average_math_df = school_data_complete["math_score"].mean()
Average_math_df = '{:,.6f}'.format(Average_math_df)
Average_math_df
# Out:
# '78.985371'

# %%
# Calculate the average reading score
Average_reading_df = school_data_complete["reading_score"].mean()
Average_reading_df = '{:,.5f}'.format(Average_reading_df)
Average_reading_df
# Out:
# '81.87784'

# %%
# Calculate the percentage of students with a passing math score (70 or greater)
Greaterthan70_math_df = school_data_complete.loc[school_data_complete["math_score"] >=70,:]
Greaterthan70_math_average_df = Greaterthan70_math_df["math_score"].count() / school_data_complete["student_name"].count()
Greaterthan70_math_average_df = '{:,.6%}'.format(Greaterthan70_math_average_df)
Greaterthan70_math_average_df
# Out:
# '74.980853%'

# %%
# Calculate the percentage of students with a passing math score (70 or greater)
Greaterthan70_reading_df = school_data_complete.loc[school_data_complete["reading_score"] >=70,:]
Greaterthan70_reading_average_df = Greaterthan70_reading_df["reading_score"].count() / school_data_complete["student_name"].count()
Greaterthan70_reading_average_df = '{:,.6%}'.format(Greaterthan70_reading_average_df)
Greaterthan70_reading_average_df
# Out:
# '85.805463%'

# %%
# Calculate the percentage of students who passed math and reading (% Overall Passing)
Greaterthan70_both_df = school_data_complete.loc[(school_data_complete["math_score"] >=70)&(school_data_complete["reading_score"] >=70)]
# Greaterthan70_both_df
Greaterthan70_both_overall_df = Greaterthan70_both_df["student_name"].count() / school_data_complete["student_name"].count()
Greaterthan70_both_overall_df = '{:,.6%}'.format(Greaterthan70_both_overall_df)
Greaterthan70_both_overall_df
# Out:
# '65.172326%'

# %%
# Create a dataframe to hold the above results
Summary_df = pd.DataFrame({"Total Schools":[Total_schools_count_df],
                           "Total Students":[Total_students_df],
                           "Total Budget":[Total_budget_sum_df],
                           "Average Math Score":[Average_math_df],
                           "Average Reading Score":[Average_reading_df],
                           "Passing Math Score":[Greaterthan70_math_average_df],
                           "Passing Reading Score":[Greaterthan70_reading_average_df],
                           "% Overall Passing":[Greaterthan70_both_overall_df]})
Summary_df
# Out:
#    Total Schools Total Students Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428          78.985371
#
#   Average Reading Score Passing Math Score Passing Reading Score  \
# 0              81.87784         74.980853%            85.805463%
#
#   % Overall Passing
# 0        65.172326%

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Create an overview table that summarizes key metrics about each school, including: 
# School Name, Total Students, Total School Budget, Average Math Score, Average Reading Score
Summary_List = school_data_complete.groupby("school_name").mean()
del Summary_List["Student ID"]
del Summary_List["School ID"]
Summary_List = Summary_List.rename(columns={"school_name":"School Name", 
                                            "size":"Total Students",
                                            "budget":"Total School Budget", 
                                            "math_score": "Average Math Score", 
                                            "reading_score":"Average Reading Score"})
Summary_List.head()
# Out:
#                       Average Reading Score  Average Math Score  \
# school_name
# Bailey High School                81.033963           77.048432
# Cabrera High School               83.975780           83.061895
# Figueroa High School              81.158020           76.711767
# Ford High School                  80.746258           77.102592
# Griffin High School               83.816757           83.351499
#
#                       Total Students  Total School Budget
# school_name
# Bailey High School            4976.0            3124928.0
# Cabrera High School           1858.0            1081356.0
# Figueroa High School          2949.0            1884411.0
# Ford High School              2739.0            1763916.0
# Griffin High School           1468.0             917500.0

# %%
# Create an overview table that summarizes key metrics about each school, including: 
# Per Student Budget
Per_Student_Budget = Summary_List["Total School Budget"]/Summary_List["Total Students"]
Summary_List["Per Student Budget"] = Per_Student_Budget
Summary_List.head()
# Out:
#                       Average Reading Score  Average Math Score  \
# school_name
# Bailey High School                81.033963           77.048432
# Cabrera High School               83.975780           83.061895
# Figueroa High School              81.158020           76.711767
# Ford High School                  80.746258           77.102592
# Griffin High School               83.816757           83.351499
#
#                       Total Students  Total School Budget  Per Student Budget
# school_name
# Bailey High School            4976.0            3124928.0               628.0
# Cabrera High School           1858.0            1081356.0               582.0
# Figueroa High School          2949.0            1884411.0               639.0
# Ford High School              2739.0            1763916.0               644.0
# Griffin High School           1468.0             917500.0               625.0

# %%
# Create an overview table that summarizes key metrics about each school, including: 
# % Passing Math
Greaterthan70_math_df = school_data_complete.loc[school_data_complete["math_score"] >=70,:]
# Greaterthan70_math_df
Greaterthan70_math_count = Greaterthan70_math_df.groupby("school_name").count()
# Greaterthan70_math_count
Greaterthan70_math_percent = Greaterthan70_math_count["math_score"] / Summary_List["Total Students"]*100
# Greaterthan70_math_percent

Summary_List["% Passing Math"] = Greaterthan70_math_percent
Summary_List.head()
# Out:
#                       Average Reading Score  Average Math Score  \
# school_name
# Bailey High School                81.033963           77.048432
# Cabrera High School               83.975780           83.061895
# Figueroa High School              81.158020           76.711767
# Ford High School                  80.746258           77.102592
# Griffin High School               83.816757           83.351499
#
#                       Total Students  Total School Budget  Per Student Budget  \
# school_name
# Bailey High School            4976.0            3124928.0               628.0
# Cabrera High School           1858.0            1081356.0               582.0
# Figueroa High School          2949.0            1884411.0               639.0
# Ford High School              2739.0            1763916.0               644.0
# Griffin High School           1468.0             917500.0               625.0
#
#                       % Passing Math
# school_name
# Bailey High School         66.680064
# Cabrera High School        94.133477
# Figueroa High School       65.988471
# Ford High School           68.309602
# Griffin High School        93.392371

# %%
# Create an overview table that summarizes key metrics about each school, including: 
# % Passing Reading

Greaterthan70_reading_df = school_data_complete.loc[school_data_complete["reading_score"] >=70,:]
Greaterthan70_reading_count = Greaterthan70_reading_df.groupby("school_name").count()
Greaterthan70_reading_percent = Greaterthan70_reading_count["reading_score"] / Summary_List["Total Students"]*100

Summary_List["% Passing Reading"] = Greaterthan70_reading_percent
Summary_List.head()
# Out:
#                       Average Reading Score  Average Math Score  \
# school_name
# Bailey High School                81.033963           77.048432
# Cabrera High School               83.975780           83.061895
# Figueroa High School              81.158020           76.711767
# Ford High School                  80.746258           77.102592
# Griffin High School               83.816757           83.351499
#
#                       Total Students  Total School Budget  Per Student Budget  \
# school_name
# Bailey High School            4976.0            3124928.0               628.0
# Cabrera High School           1858.0            1081356.0               582.0
# Figueroa High School          2949.0            1884411.0               639.0
# Ford High School              2739.0            1763916.0               644.0
# Griffin High School           1468.0             917500.0               625.0
#
#                       % Passing Math  % Passing Reading
# school_name
# Bailey High School         66.680064          81.933280
# Cabrera High School        94.133477          97.039828
# Figueroa High School       65.988471          80.739234
# Ford High School           68.309602          79.299014
# Griffin High School        93.392371          97.138965

# %%
# Create an overview table that summarizes key metrics about each school, including: 
# % Overall Passing

# # # Not working
# Greaterthan70_both_df = school_data_complete.loc[(school_data_complete["math_score"] >=70)&(school_data_complete["reading_score"] >=70)]
# # Greaterthan70_both_df
# Greaterthan70_both_count = Greaterthan70_both_df["school_name"].count() 
# # Greaterthan70_both_count

# Greaterthan70_both_percent = Greaterthan70_both_count["math_score"] / Summary_List["Total Students"]*100
# Greaterthan70_both_percent

Summary_List["% Passing Overall"] = (Summary_List["% Passing Math"]+Summary_List["% Passing Reading"])/2
Summary_List.head()
# Out:
#                       Average Reading Score  Average Math Score  \
# school_name
# Bailey High School                81.033963           77.048432
# Cabrera High School               83.975780           83.061895
# Figueroa High School              81.158020           76.711767
# Ford High School                  80.746258           77.102592
# Griffin High School               83.816757           83.351499
#
#                       Total Students  Total School Budget  Per Student Budget  \
# school_name
# Bailey High School            4976.0            3124928.0               628.0
# Cabrera High School           1858.0            1081356.0               582.0
# Figueroa High School          2949.0            1884411.0               639.0
# Ford High School              2739.0            1763916.0               644.0
# Griffin High School           1468.0             917500.0               625.0
#
#                       % Passing Math  % Passing Reading  % Passing Overall
# school_name
# Bailey High School         66.680064          81.933280          74.306672
# Cabrera High School        94.133477          97.039828          95.586652
# Figueroa High School       65.988471          80.739234          73.363852
# Ford High School           68.309602          79.299014          73.804308
# Griffin High School        93.392371          97.138965          95.265668

# %%
# Create an overview table that summarizes key metrics about each school, including: 
# School Type
School_Type = school_data_complete.loc[:,["school_name" , "type"]]
Summary_List_Type = pd.merge(Summary_List, School_Type, on="school_name", how="inner")
Summary_List_Type.drop_duplicates(inplace=True)
# Summary_List_Type.reset_index(drop=True)

Summary_List_Type = Summary_List_Type.rename(columns={"type":"School Type"})
Summary_List_Type.head()
# Out:
#                 school_name  Average Reading Score  Average Math Score  \
# 0        Bailey High School              81.033963           77.048432
# 4976    Cabrera High School              83.975780           83.061895
# 6834   Figueroa High School              81.158020           76.711767
# 35087       93.867718          96.539641          95.203679
# 37370       93.333333          96.611111          94.972222

# %%
# Format output
Summary_List_Organise.style.format({"Total Students": "{:,.0f}", 
                                    "Total School Budget": "${:,.2f}", 
                                    "Per Student Budget": "${:,.2f}", 
                                    "Average Math Score": "{:,.6f}", 
                                    "Average Reading Score": "{:,.6f}", 
                                    "% Passing Math": "{:,.6f}", 
                                    "% Passing Reading": "{:,.6f}", 
                                    "% Overall Passing": "{:,.6f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_108b5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >school_name</th>
#       <th class="col_heading level0 col1" >School Type</th>
#       <th class="col_heading level0 col2" >Total Students</th>
#       <th class="col_heading level0 col3" >Total School Budget</th>
#       <th class="col_heading level0 col4" >Per Student Budget</th>
#       <th class="col_heading level0 col5" >Average Math Score</th>
#       <th class="col_heading level0 col6" >Average Reading Score</th>
#       <th class="col_heading level0 col7" >% Passing Math</th>
#       <th class="col_heading level0 col8" >% Passing Reading</th>
#       <th class="col_heading level0 col9" >% Passing Overall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_108b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_108b5_row0_col0" class="data row0 col0" >Bailey High School</td>
#       <td id="T_108b5_row0_col1" class="data row0 col1" >District</td>
#       <td id="T_108b5_row0_col2" class="data row0 col2" >4,976</td>
#       <td id="T_108b5_row0_col3" class="data row0 col3" >$3,124,928.00</td>
#       <td id="T_108b5_row0_col4" class="data row0 col4" >$628.00</td>
#       <td id="T_108b5_row0_col5" class="data row0 col5" >77.048432</td>
#       <td id="T_108b5_row0_col6" class="data row0 col6" >81.033963</td>
#       <td id="T_108b5_row0_col7" class="data row0 col7" >66.680064</td>
#       <td id="T_108b5_row0_col8" class="data row0 col8" >81.933280</td>
#       <td id="T_108b5_row0_col9" class="data row0 col9" >74.306672</td>
#     </tr>
#     <tr>
#       <th id="T_108b5_level0_row1" class="row_heading level0 row1" >4976</th>
#       <td id="T_108b5_row1_col0" class="data row1 col0" >Cabrera High School</td>
#       <td id="T_108b5_row1_col1" class="data row1 col1" >Charter</td>
#       <td id="T_108b5_row1_col2" class="data row1 col2" >1,858</td>
#       <td id="T_108b5_row1_col3" class="data row1 col3" >$1,081,356.00</td>
#       <td id="T_108b5_row1_col4" class="data row1 col4" >$582.00</td>
#       <td id="T_108b5_row1_col5" class="data row1 col5" >83.061895</td>
#       <td id="T_108b5_row1_col6" class="data row1 col6" >83.975780</td>
#       <td id="T_108b5_row1_col7" class="data row1 col7" >94.133477</td>
#       <td id="T_108b5_row1_col8" class="data row1 col8" >97.039828</td>
#       <td id="T_108b5_row1_col9" class="data row1 col9" >95.586652</td>
#     </tr>
#     <tr>
#       <th id="T_108b5_level0_row2" class="row_heading level0 row2" >6834</th>
#       <td id="T_108b5_row2_col0" class="data row2 col0" >Figueroa High School</td>
#       <td id="T_108b5_row2_col1" class="data row2 col1" >District</td>
#       <td id="T_108b5_row2_col2" class="data row2 col2" >2,949</td>
#       <td id="T_108b5_row2_col3" class="data row2 col3" >$1,884,411.00</td>
#       <td id="T_108b5_row2_col4" class="data row2 col4" >$639.00</td>
#       <td id="T_108b5_row2_col5" class="data row2 col5" >76.711767</td>
#       <td id="T_108b5_row2_col6" class="data row2 col6" >81.158020</td>
#       <td id="T_108b5_row2_col7" class="data row2 col7" >65.988471</td>
#       <td id="T_108b5_row2_col8" class="data row2 col8" >80.739234</td>
#       <td id="T_108b5_row2_col9" class="data row2 col9" >73.363852</td>
#     </tr>
#     <tr>
#       <th id="T_108b5_level0_
td>
#     </tr>
#     <tr>
#       <th id="T_108b5_level0_row6" class="row_heading level0 row6" >18625</th>
#       <td id="T_108b5_row6_col0" class="data row6 col0" >Holden High School</td>
#       <td id="T_108b5_row6_col1" class="data row6 col1" >Charter</td>
#       <td id="T_108b5_row6_col2" class="data row6 col2" >427</td>
#       <td id="T_108b5_row6_col3" class="data row6 col3" >$248,087.00</td>
#       <td id="T_108b5_row6_col4" class="data row6 col4" >$581.00</td>
#       <td id="T_108b5_row6_col5" class="data row6 col5" >83.803279</td>
#       <td id="T_108b5_row6_col6" class="data row6 col6" >83.814988</td>
#       <td id="T_108b5_row6_col7" class="data row6 col7" >92.505855</td>
#       <td id="T_108b5_row6_col8" class="data row6 col8" >96.252927</td>
#       <td id="T_108b5_row6_col9" class="data row6 col9" >94.379391</td>
#     </tr>
#     <tr>
#       <th id="T_108b5_level0_row7" class="row_heading level0 row7" >19052</th>
#       <td id="T_108b5_row7_col0" class="data row7 col0" >Huang High School</td>
#       <td id="T_108b5_row7_col1" class="data row7 col1" >District</td>
#       <td id="T_108b5_row7_col2" class="data row7 col2" >2,917</td>
#       <td id="T_108b5_row7_col3" class="data row7 col3" >$1,910,635.00</td>
#       <td id="T_108b5_row7_col4" class="data row7 col4" >$655.00</td>
#       <td id="T_108b5_row7_col5" class="data row7 col5" >76.629414</td>
#       <td id="T_108b5_row7_col6" class="data row7 col6" >81.182722</td>
#       <td id="T_108b5_row7_col7" class="data row7 col7" >65.683922</td>
#       <td id="T_108b5_row7_col8" class="data row7 col8" >81.316421</td>
#       <td id="T_108b5_row7_col9" class="data row7 col9" >73.500171</td>
#     </tr>
#     <tr>
#       <th id="T_108b5_level0_row8" class="row_heading level0 row8" >21969</th>
#       <td id="T_108b5_row8_col0" class="data row8 col0" >Johnson High School</td>
#       <td id="T_108b5_row8_col1" class="data row8 col1" >District</td>
#       <td id="T_108b5_row8_col2" class="data row8 col2" >4,761</td>
#       <td id="T_108b5_row8_col3" class="data row8 col3" >$3,094,650.00</td>
#       <td id="T_108b5_row8_col4" class="data row8 col4" >$650.00</td>
#       <td id="T_108b5_row8_col5" class="data row8 col5" >77.072464</td>
#       <td id="T_108b5_row8_col6" class="data row8 col6" >80.966394</td>
#       <td id="T_108b5_

# %%
# dont enter here
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# Thomas High School        Charter            1635       $1,043,130.00
# Wilson High School        Charter            2283       $1,319,574.00
# Wright High School        Charter            1800       $1,049,400.00
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School               $628.00           77.048432
# Cabrera High School              $582.00           83.061895
# Figueroa High School             $639.00           76.711767
# Ford High School                 $644.00           77.102592
# Griffin High School              $625.00           83.351499
# Hernandez High School            $652.00           77.289752
# Holden High School               $581.00           83.803279
# Huang High School                $655.00           76.629414
# Johnson High School              $650.00           77.072464
# Pena High School                 $609.00           83.839917
# Rodriguez High School            $637.00           76.842711
# Shelton High School              $600.00           83.359455
# Thomas High School               $638.00           83.418349
# Wilson High School               $578.00           83.274201
# Wright High School               $583.00           83.682222
#
#                        Average Reading Score  % Passing Math  \
# Bailey High School                 81.033963       66.680064
# Cabrera High School                83.975780       94.133477
# Figueroa High School               81.158020       65.988471
# Ford High School                   80.746258       68.309602
# Griffin High School                83.816757       93.392371
# Hernandez High School              80.934412       66.752967
# Holden High School                 83.814988       92.505855
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Pena High School                   84.044699       94.594595
# Rodriguez High School              80.744686       66.366592
# Shelton High School                83.725724       93.867121
# Thomas High School                 83.848930       93.272171
# Wilson High School                 83.989488       93.867718
# Wright High School                 83.955000       93.333333
#
#                        % Passing Reading  % Overall Passing
# Bailey High School             81.933280          54.642283
# Cabrera High School            97.039828          91.334769
# Figueroa High School           80.739234          53.204476
# Ford High School               79.299014          54.289887
# Griffin High School            97.138965          90.599455
# Hernandez High School          80.862999          53.527508
# Holden High School             96.252927          89.227166
# Huang High School              81.316421          53.513884
# Johnson High School            81.222432          53.539172
# Pena High School               95.945946          90.540541
# Rodriguez High School          80.220055          52.988247
# Shelton High School            95.854628          89.892107
# Thomas High School             97.308869          90.948012
# Wilson High School             96.539641          90.582567
# Wright High School             96.611111          90.333333

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# Thomas High School               83.848930       93.272171          97.308869
# Griffin High School              83.816757       93.392371          97.138965
# Wilson High School               83.989488       93.867718          96.539641
# Pena High School                 84.044699       94.594595          95.945946
#
#                      % Overall Passing
# Cabrera High School          91.334769
# Thomas High School           90.948012
# Griffin High School          90.599455
# Wilson High School           90.582567
# Pena High School             90.540541

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# Figueroa High School               81.158020       65.988471
# Huang High School                  81.182722       65.683922
# Hernandez High School              80.934412       66.752967
# Johnson High School                80.966394       66.057551
#
#                        % Passing Reading  % Overall Passing
# Rodriguez High School          80.220055          52.988247
# Figueroa High School           80.739234          53.204476
# Huang High School              81.316421          53.513884
# Hernandez High School          80.862999          53.527508
# Johnson High School            81.222432          53.539172

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# Wilson High School     83.939778  84.021452  83.764608  84.317673
# Wright High School     83.833333  83.812757  84.156322  84.073171

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                       83.46                  83.93
# $585-630                                    81.90                  83.16
# $630-645                                    78.52                  81.62
# $645-680                                    77.00                  81.03
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                                   93.46              96.61
# $585-630                                87.13              92.72
# $630-645                                73.48              84.39
# $645-680                                66.16              81.13
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                      90.37
# $585-630                                   81.42
# $630-645                                   62.86
# $645-680                                   53.53

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
